# %%
import pandas as pd

# %%
gore_00 = pd.read_csv('gore_00_1.csv')

gore_00['contributor_split'] = gore_00['contributor_employer'].str.split('/')

occ = []
for index, row in gore_00.iterrows():
    if row['contributor_split'] != None:
        if type(row['contributor_split']) != float:
            if len(row['contributor_split']) == 2:
                occ.append(row['contributor_split'][1])
            else:
                occ.append(row['contributor_split'][0])
        else:
            occ.append(row['contributor_split'])
    else:
        occ.append(None)
    

gore_00['contributor_occupation'] = occ

gore_00.to_csv('gore_00.csv')

gore_00.head()
# Out:
#   committee_id                                     committee_name  \
# 0    C00342212  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 1    C00342212  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 2    C00342212  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 3    C00342212  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 4    C00342212  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
#
#    report_year report_type  image_number  line_number  transaction_id  \
# 0         2000         M10   20990231812          NaN             NaN
# 1         2000         M10   20990231812          NaN             NaN
# 2         2000         M10   20990231812          NaN             NaN
# 3         2000         M10   20990231812          NaN             NaN
# 4         2000         M10   20990231812          NaN             NaN
#
#    file_number                                   committee_name.1  \
# 0          NaN  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 1          NaN  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 2          NaN  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 3          NaN  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
# 4          NaN  GORE/LIEBERMAN GENERAL ELECTION LEGAL AND ACCO...
#
#    entity_type  ...              link_id  is_individual  memo_text  \
# 0          NaN  ...  3040720021023402138              t        NaN
# 1          NaN  ...  3040720021023402138              t        NaN
# 2          NaN  ...  3040720021023402138              t        NaN
# 3          NaN  ...  3040720021023402138              t        NaN
# 4          NaN  ...  3040720021023402138              t        NaN
#
#   two_year_transaction_period schedule_type  increased_limit  \
# 0                        2000            SA              NaN
# 1                        2000            SA              NaN
# 2                        2000            SA              NaN
# 3                        2000            SA              NaN
# 4                        2000            SA              NaN
#
#                 sub_id                                            pdf_url  \
# 0  3061920110007561966  http://docquery.fec.gov/cgi-bin/fecimg/?209902...
# 1  3061920110007561967  http://docquery.fec.gov/cgi-bin/fecimg/?209902...
# 2  3061920110007561968  http://docquery.fec.gov/cgi-bin/fecimg/?209902...
# 3  3061920110007561969  http://docquery.fec.gov/cgi-bin/fecimg/?209902...
# 4  3061920110007561970  http://docquery.fec.gov/cgi-bin/fecimg/?209902...
#
#    line_number_label                     contributor_split
# 0                NaN  [SELF EMPLOYED, PLANNING CONSULTANT]
# 1                NaN           [SELF EMPLOYED, ART DEALER]
# 2                NaN             [FERMILAB, ADMINISTRATOR]
# 3                NaN               [NOT EMPLOYED, RETIRED]
# 4                NaN               [NOT EMPLOYED, RETIRED]
#
# [5 rows x 80 columns]
