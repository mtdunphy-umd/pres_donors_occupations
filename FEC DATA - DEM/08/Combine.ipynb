# %%
import pandas as pd

# %%
first = pd.read_csv("obama_08_1.csv", low_memory=False).sample(frac=.25)
second = pd.read_csv("obama_08_2.csv", low_memory=False).sample(frac=.25)
third = pd.read_csv("obama_08_3.csv", low_memory=False).sample(frac=.25)
fourth = pd.read_csv("obama_08_4.csv", low_memory=False).sample(frac=.25)
fifth = pd.read_csv("obama_08_5.csv", low_memory=False).sample(frac=.25)

# %%
combine1 = first.append(second, ignore_index=True)
combine2 = combine1.append(third, ignore_index=True)
combine3 = combine2.append(fourth, ignore_index=True)
combine = combine3.append(fifth, ignore_index=True)

combine.to_csv('obama_08.csv', index = False)

combine.head()
# Out:
#   committee_id     committee_name  report_year report_type  image_number  \
# 0    C00431445  OBAMA FOR AMERICA         2008         M10   11972595018
# 1    C00431445  OBAMA FOR AMERICA         2008          M9   11972641055
# 2    C00431445  OBAMA FOR AMERICA         2008         30G   11953153605
# 3    C00431445  OBAMA FOR AMERICA         2008         M10   11972609862
# 4    C00431445  OBAMA FOR AMERICA         2008          M9   11972696685
#
#   line_number transaction_id  file_number  committee_name.1 entity_type  ...  \
# 0         17A        8191695       753817               NaN         IND  ...
# 1         17A        6292296       753821               NaN         IND  ...
# 2         17A       11249893       754317               NaN         IND  ...
# 3          18       T9705864       753817               NaN         IND  ...
# 4          18       T7486270       753821               NaN         IND  ...
#
# ...
