# %%
import pandas as pd

# %%
combine = pd.read_csv("obama_12_1.csv").sample(frac=.25)
for x in range(2, 7):
    temp = pd.read_csv("obama_12_" + str(x) + ".csv").sample(frac=.25)
    combine.append(temp, ignore_index=True)
    
combine.to_csv('obama_12.csv')

combine.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,25,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,25,28,29,32,55,67,68,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,25,28,29,32,56,67,68) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...
