# %%
import pandas as pd

# %%
data = pd.read_csv('bush_92_1.csv')

data['contributor_split'] = data['contributor_employer'].str.split('/')

occ = []
for index, row in data.iterrows():
    if row['contributor_split'] != None:
        if type(row['contributor_split']) != float:
            if len(row['contributor_split']) == 2:
                occ.append(row['contributor_split'][1])
            else:
                occ.append(row['contributor_split'][0])
        else:
            occ.append(row['contributor_split'])
    else:
        occ.append(None)
    

data['contributor_occupation'] = occ

data.to_csv('bush_92.csv')

data.head()
# Out:
#   committee_id                              committee_name  report_year  \
# 0    C00273516       BUSH-QUAYLE '92 GENERAL COMMITTEE INC         1992
# 1    C00255380  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC         1992
# 2    C00255380  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC         1992
# 3    C00255380  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC         1992
# 4    C00255380  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC         1992
#
#   report_type  image_number  line_number  transaction_id  file_number  \
# 0         M10   94039172259          NaN             NaN          NaN
# 1         M10   92037904328          NaN             NaN          NaN
# 2         M10   92037904337          NaN             NaN          NaN
# 3         M10   92037904332          NaN             NaN          NaN
# 4         M10   92037904333          NaN             NaN          NaN
#
#                              committee_name.1  entity_type  ...  \
# 0       BUSH-QUAYLE '92 GENERAL COMMITTEE INC          NaN  ...
# 1  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC          NaN  ...
# 2  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC          NaN  ...
# 3  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC          NaN  ...
# 4  BUSH - QUAYLE '92 COMPLIANCE COMMITTEE INC          NaN  ...
#
#                link_id  is_individual  memo_text two_year_transaction_period  \
# 0  3032920021022249450              t        NaN                        1992
# 1  3032920021022249462              t        NaN                        1992
# 2  3032920021022249462              t        NaN                        1992
# 3  3032920021022249462              t        NaN                        1992
# 4  3032920021022249462              t        NaN                        1992
#
#   schedule_type  increased_limit               sub_id  \
# 0            SA              NaN  3061920110003320034
# 1            SA              NaN  3061920110003374848
# 2            SA              NaN  3061920110003374894
# 3            SA              NaN  3061920110003374867
# 4            SA              NaN  3061920110003374875
#
#                                              pdf_url  line_number_label  \
# 0  http://docquery.fec.gov/cgi-bin/fecimg/?940391...                NaN
# 1  http://docquery.fec.gov/cgi-bin/fecimg/?920379...                NaN
# 2  http://docquery.fec.gov/cgi-bin/fecimg/?920379...                NaN
# 3  http://docquery.fec.gov/cgi-bin/fecimg/?920379...                NaN
# 4  http://docquery.fec.gov/cgi-bin/fecimg/?920379...                NaN
#
#               contributor_split
# 0        [RPR & ASSOCIATES INC]
# 1  [COMMUNICOM CORP OF AMERICA]
# 2                           NaN
# 3  [NAT'L COMM FOR EMPL POLICY]
# 4                           NaN
#
# [5 rows x 80 columns]
