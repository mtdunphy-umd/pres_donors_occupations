# %%
import pandas as pd

# %%
data = pd.read_csv('bush_00_1.csv')

data['contributor_split'] = data['contributor_employer'].str.split('/')

occ = []
for index, row in data.iterrows():
    if row['contributor_split'] != None:
        if type(row['contributor_split']) != float:
            if len(row['contributor_split']) == 2:
                occ.append(row['contributor_split'][1])
            else:
                occ.append(row['contributor_split'][0])
        else:
            occ.append(row['contributor_split'])
    else:
        occ.append(None)
    

data['contributor_occupation'] = occ

data.to_csv('bush_00.csv')

data.head()
# Out:
#   committee_id                             committee_name  report_year  \
# 0    C00346932  BUSH-CHENEY 2000 COMPLIANCE COMMITTEE INC         2000
# 1    C00346932  BUSH-CHENEY 2000 COMPLIANCE COMMITTEE INC         2000
# 2    C00346932  BUSH-CHENEY 2000 COMPLIANCE COMMITTEE INC         2000
# 3    C00346932  BUSH-CHENEY 2000 COMPLIANCE COMMITTEE INC         2000
# 4    C00346932  BUSH-CHENEY 2000 COMPLIANCE COMMITTEE INC         2000
#
#   report_type  image_number  line_number  transaction_id  file_number  \
# 0         M10   20990230754          NaN             NaN          NaN
# 1         M10   20990230754          NaN             NaN          NaN
# 2         M10   20990230754          NaN             NaN          NaN
# 3         M10   20990230755          NaN             NaN          NaN
# 4         M10   20990230755          NaN             NaN          NaN
#
#                             committee_name.1  entity_type  ...  \
# ...
